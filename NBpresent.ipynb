# %% [markdown]
# <center><H1> Plotting a nice plot with Py-ART</H1>
# <i> Scott Collis, Jonathan Helmus</center>

# %%
import numpy as np
from matplotlib import pyplot as plt
import pyart
from IPython import display
# %matplotlib inline

# %%
# create the plot using RadarDisplay
sweep = 0
# read file
radar = pyart.io.read_mdv('/Users/scollis/Dropbox/Public/224356.mdv')
display = pyart.graph.RadarDisplay(radar)
fig = plt.figure(figsize=[20, 5])
ax = fig.add_subplot(111)

# plot velocity
display.plot('reflectivity', sweep=sweep, vmin=-8, vmax=64, fig=fig,
             ax=ax, cmap='pyart_NWSRef', colorbar_label='Reflectivity (dBz)')
display.set_limits( ylim=[0, 15])

# %% [markdown]
# <center><H1> About Py-ART</H1></center>

# %% [markdown]
# * The Python ARM Radar Toolkit is a data model driven way of working with radar data
# * Python with some Cython and FOTRAN
# * Supported by DoE ARM, many 3rd party developers

# %%
display.Image('http://www.arm.gov/images/template/logo.png')
