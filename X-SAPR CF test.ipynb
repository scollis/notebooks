# %%
from numpy import *
import matplotlib.pyplot as plt

basedir='/Users/scollis/local_modules/pyart/'
import sys
sys.path.append(basedir)
import pyart

# %%
reload(pyart)
# Out:
# <module 'pyart' from '/Users/scollis/local_modules/pyart/pyart/__init__.pyc'>

# %%
radar = pyart.io.read_rsl('/data/XSW130401000245.RAWWLTJ')

# %%
print radar.fields.keys()
# Out:
# ['reflectivity_horizontal', 'mean_doppler_velocity', 'diff_phase', 'norm_coherent_power', 'dp_phase_shift', 'diff_reflectivity', 'reflectivity_horizontal_filtered', 'copol_coeff']

# %%
display = pyart.graph.RadarDisplay(radar)
fig = plt.figure()
ax = fig.add_subplot(111)
display.plot_ppi('reflectivity_horizontal_filtered', 0, vmin=-16, vmax=64)

# %%
display = pyart.graph.RadarDisplay(radar)
fig = plt.figure()
ax = fig.add_subplot(111)
display.plot_ppi('reflectivity_horizontal', 0, vmin=-16, vmax=64)
