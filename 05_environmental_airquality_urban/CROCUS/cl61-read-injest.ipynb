# %%
import act
import glob
import matplotlib.pyplot as plt
import matplotlib
import pyart
import xarray as xr
import datetime
import numpy as np
import pandas as pd
from matplotlib.dates import DateFormatter
import os

# %matplotlib inline
# Out:
# ## You are using the Python ARM Radar Toolkit (Py-ART), an open source
# ## library for working with weather radar data. Py-ART is partly
# ## supported by the U.S. Department of Energy as part of the Atmospheric
# ## Radiation Measurement (ARM) Climate Research Facility, an Office of
# ## Science user facility.
# ##
# ## If you use this software to prepare a publication, please cite:
# ##
# ##     JJ Helmus and SM Collis, JORS 2016, doi: 10.5334/jors.119

# %%
ds = act.io.read_netcdf('/Volumes/T7/data/cl61_ingested/crocus-neiu-ceilometer-a1-202306270000.nc')

# %%
# %matplotlib inline
figme = plt.figure(figsize=[16,5])
ds.backscatter.transpose().plot( cmap=pyart.graph.cm_colorblind.ChaseSpectral, vmin = -8)
#plt.ylim([0,15000])
date_form = DateFormatter("%Y-%m-%d \n %H:%M:%S")
plt.gca().xaxis.set_major_formatter(date_form)
plt.savefig('/Users/scollis/jout.png')

# %%
figme = plt.figure(figsize=[16,5])
ds.linear_depol_ratio.transpose().plot( cmap=pyart.graph.cm_colorblind.ChaseSpectral, vmax=.6, vmin=-.2)
#plt.ylim([0,5000])
date_form = DateFormatter("%Y-%m-%d \n %H:%M:%S")
plt.gca().xaxis.set_major_formatter(date_form)

# %%
files = glob.glob('/Volumes/T7/data/cl61_ingested_early/crocus-neiu-ceilometer-a1-20230*') +\
        glob.glob('/Volumes/T7/data/cl61_ingested/crocus-neiu-ceilometer-a1-20230*')
ds = act.io.read_netcdf(files)
# Out:
# /Users/scollis/miniconda3/envs/crocus/lib/python3.11/site-packages/xarray/core/indexing.py:1374: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
#     ...     array[indexer]
#   return self.array[key]
# /Users/scollis/miniconda3/envs/crocus/lib/python3.11/site-packages/xarray/core/indexing.py:1374: PerformanceWarning: Slicing is producing a large chunk. To accept the large
# chunk and silence this warning, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': False}):
#     ...     array[indexer]
#
# To avoid creating the large chunks, set the option
#     >>> with dask.config.set(**{'array.slicing.split_large_chunks': True}):
# ...

# %%
figme = plt.figure(figsize=[16,5])
ds.backscatter.transpose().plot( cmap=pyart.graph.cm_colorblind.ChaseSpectral, vmin = -8, vmax=-4)
#plt.ylim([0,15000])
date_form = DateFormatter("%Y-%m-%d \n %H:%M:%S")
plt.gca().xaxis.set_major_formatter(date_form)

# %%
ds.time
# Out:
# <xarray.DataArray 'time' (time: 33060)>
# array(['2023-05-27T14:45:00.441000000', '2023-05-27T14:46:00.410000000',
#        '2023-05-27T14:47:00.631000000', ..., '2023-06-19T13:42:01.699000000',
#        '2023-06-19T13:43:01.519000000', '2023-06-19T13:44:01.604000000'],
#       dtype='datetime64[ns]')
# Coordinates:
#   * time       (time) datetime64[ns] 2023-05-27T14:45:00.441000 ... 2023-06-1...
#     longitude  float64 -87.72
#     latitude   float64 41.98

# %%
ds = act.io.read_netcdf('/Volumes/T7/data/cl61_ingested_early/crocus-neiu-ceilometer-a1-202306')

# %%
figme = plt.figure(figsize=[16,5])
ds.backscatter.transpose().plot( cmap=pyart.graph.cm_colorblind.ChaseSpectral, vmin = -8)
#plt.ylim([0,15000])
date_form = DateFormatter("%Y-%m-%d \n %H:%M:%S")
plt.gca().xaxis.set_major_formatter(date_form)

# %%
ds2 = act.io.read_netcdf('/Volumes/T7/data/cl61_ingested/crocus-neiu-ceilometer-a1-202306280000.nc')

# %%
figme = plt.figure(figsize=[16,5])
ds2.backscatter.transpose().plot( cmap=pyart.graph.cm_colorblind.ChaseSpectral, vmin = -8)
#plt.ylim([0,15000])
date_form = DateFormatter("%Y-%m-%d \n %H:%M:%S")
plt.gca().xaxis.set_major_formatter(date_form)

# %%
ds_joined = act.io.read_netcdf(glob.glob('/Volumes/T7/data/cl61_ingested/crocus-neiu-ceilometer-a1-202307*'))

# %%
figme = plt.figure(figsize=[16,5])
ds_joined.backscatter.transpose().plot( cmap=pyart.graph.cm_colorblind.ChaseSpectral, vmin = -8)
plt.ylim([0,5000])
date_form = DateFormatter("%Y-%m-%d \n %H:%M:%S")
plt.gca().xaxis.set_major_formatter(date_form)
plt.tight_layout()
plt.savefig('/Users/scollis/jout.png')
