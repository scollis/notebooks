# %%
#first we do some imports and check the version of Py-ART for consistency
import pyart
from matplotlib import pyplot as plt
import netCDF4
import numpy as np
from copy import deepcopy
import copy
import scipy
from matplotlib import rc
from netCDF4 import num2date
# %matplotlib inline
print pyart.__version__
# Out:
# 1.0.0.dev-bfd657f

# %%
filename = '/data/THAI_000230.mdv'
radar = pyart.io.read(filename, file_field_names = True)

# %%
print radar.fields.keys()
print radar.longitude['data']
print radar.latitude['data']
# Out:
# ['DBZ']
# [ 100.96583557]
# [ 12.64722157]

# %%
print radar.azimuth['data']
# Out:
# [   0.    1.    2. ...,  357.  358.  359.]

# %%
print radar.elevation['data']
# Out:
# [  0.60000002   0.60000002   0.60000002 ...,  25.          25.          25.        ]

# %%
print radar.time['units']
# Out:
# seconds since 2014-02-28T23:48:06Z

# %%
display = pyart.graph.RadarMapDisplay(radar)
plt.figure(figsize=[14,8])
display.plot_ppi_map('DBZ', 0, vmin=-8, vmax=64, lat_lines=np.arange(10,20,.5),
                     lon_lines =  np.arange(90,110,2), resolution = 'h')
display.basemap.drawrivers()
display.basemap.drawcountries()
display.plot_range_rings([100, 200])
#display.set_limits(ylim=[-100, 100], xlim=[-100,100])
