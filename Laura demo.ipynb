# %%
import netCDF4
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
site = 'http://thredds.ucar.edu/thredds/dodsC/grib/NCEP/GFS/Global_0p5deg_ana/GFS_Global_0p5deg_ana_20160120_0000.grib2'
fh = netCDF4.Dataset(site)

# %%
print fh.variables.keys()
# Out:
# [u'lat', u'lon', u'reftime', u'time', u'pressure_difference_layer', u'altitude_above_msl', u'isobaric', u'height_above_ground', u'sigma', u'pressure_difference_layer1', u'isobaric1', u'isobaric2', u'sigma_layer', u'isobaric3', u'potential_vorticity_surface', u'isobaric4', u'LatLon_Projection', u'pressure_difference_layer_bounds', u'pressure_difference_layer1_bounds', u'sigma_layer_bounds', u'Absolute_vorticity_isobaric', u'Cloud_mixing_ratio_isobaric', u'Cloud_water_entire_atmosphere_single_layer', u'Convective_available_potential_energy_surface', u'Convective_available_potential_energy_pressure_difference_layer', u'Convective_inhibition_surface', u'Convective_inhibition_pressure_difference_layer', u'Geopotential_height_surface', u'Geopotential_height_isobaric', u'Geopotential_height_zeroDegC_isotherm', u'Geopotential_height_potential_vorticity_surface', u'Geopotential_height_maximum_wind', u'Geopotential_height_tropopause', u'Geopotential_height_highest_tropospheric_freezing', u'ICA
# ...

# %%
print fh.variables['MSLP_Eta_model_reduction_msl'].shape
# Out:
# (1, 361, 720)

# %%
plt.plot(fh.variables['MSLP_Eta_model_reduction_msl'][0, 150,:])

# %%
plt.pcolormesh(fh.variables['MSLP_Eta_model_reduction_msl'][when_cloudy, :,:])
# Out:
# /Users/scollis/anaconda/lib/python2.7/site-packages/matplotlib/collections.py:590: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):
