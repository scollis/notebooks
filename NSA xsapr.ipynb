# %%
import pyart
import numpy as np
from matplotlib import pyplot as plt
from copy import deepcopy
from netCDF4 import num2date, date2num, Dataset

# %matplotlib inline

# %%
fname = '/data/cfrad.20130113_211209.776_to_20130113_211533.741_loca_v1_RHI.nc'
radar = pyart.io.read(fname)

# %%
print(radar.fields.keys())
# Out:
# [u'PHIDP', u'UNKNOWN', u'DBZ_CORR', u'ZDR', u'WIDTH', u'SQI', u'DBZ', u'RHOHV', u'VEL', u'KDP', u'DBZ_TOT']

# %%
plt.figure(figsize=[16,10])
plt.pcolormesh(radar.fields['DBZ_CORR']['data'].transpose(), vmin=-30, vmax=10)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x115f39dd0>

# %%
plt.figure(figsize=[16,10])
plt.pcolormesh(radar2.fields['DBZ_CORR']['data'].transpose(), vmin=-30, vmax=10)
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x115ede758>
