# %%
import pyart
from matplotlib import pyplot as plt
import copy
import numpy as np
from numpy import ma
from time import time
# %matplotlib inline

# %%
fn = '/data/xstage/sgpxsaprI6.00.20150417.111201.maint.XNW150417100740.RAWL0UT.maint'
radar = pyart.io.read(fn)

# %%
min_lon=-99.
max_lon=-96.
min_lat=35.7
max_lat=38.
lon_lines=[-95, -96, -97, -98, -99]
lat_lines=[35,36,37,38]

# %%
#create an instance of the class using our radar
display = pyart.graph.RadarDisplay(radar)
#create a Matplotlib figure
fig = plt.figure(figsize = [15,3])
plt.subplot(1,2,1)
display.plot_rhi('differential_phase', sweep = 1, vmin = 0, vmax = 360)
plt.ylim([0,5])

plt.subplot(1,2,2)
display.plot_rhi('reflectivity', sweep = 1, vmin = -16, vmax = 64)
plt.ylim([0,5])
# Out:
# (0, 5)

# %%
plt.plot(radar.elevation['data'])
plt.ylim([0,20])
# Out:
# (0, 20)

# %%
#create an instance of the class using our radar
display = pyart.graph.RadarMapDisplay(radar)
#create a Matplotlib figure
f = plt.figure(figsize = [17,4])
#now we are going to do a three panel plot, resolution is a basemap parameter and determines the resolution of 
#the coastline.. here we set to intermediate or 'i' ('h' for high 'l' for low)
plt.subplot(1, 3, 1) 
display.plot_ppi_map('differential_reflectivity', sweep = 0, vmin = -2, vmax = 6, 
                     min_lon = min_lon, max_lon = max_lon, min_lat = min_lat, max_lat = max_lat,
                     resolution = 'i')
plt.subplot(1, 3, 2) 
display.plot_ppi_map('reflectivity', sweep = 0, vmin = -8, vmax = 64,
                      min_lon = min_lon, max_lon = max_lon, min_lat = min_lat, max_lat = max_lat,
                     resolution = 'i')
plt.subplot(1, 3, 3) 
display.plot_ppi_map('velocity', sweep = 0, vmin = -17, vmax = 17,
                      min_lon = min_lon, max_lon = max_lon, min_lat = min_lat, max_lat = max_lat,
                     resolution = 'i')
