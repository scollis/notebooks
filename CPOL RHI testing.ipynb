# %%
import pyart
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
filename =  '/data/output/20060123/cfrad.20060123_071852.000_to_20060123_071911.000_CPOL_v1_PPI.nc'
#filename = '/data/testrsluf.uf'
radar = pyart.io.read(filename)

# %%
# read the data and create the display object
display = pyart.graph.RadarDisplay(radar)

# fields to plot and ranges
fields_to_plot = ['DZ', 'VR']
ranges = [(-32, 64), (-17.0, 17.0)]

# plot the data
nplots = len(fields_to_plot)
plt.figure(figsize=[5 * nplots, 4])

# plot each field
for plot_num in xrange(nplots):
    field = fields_to_plot[plot_num]
    vmin, vmax = ranges[plot_num]

    plt.subplot(1, nplots, plot_num + 1)
    display.plot_rhi(field, 0, vmin=vmin, vmax=vmax, title_flag=False)
    display.set_limits(ylim=[0, 17])

# set the figure title and show
radar_name = display.radar_name
time_text = ' ' + display.time_begin.isoformat() + 'Z '
azimuth = radar.fixed_angle['data'][0]
title = 'RHI ' + radar_name + time_text + 'Azimuth %.2f' % (azimuth)
plt.suptitle(title)

# %%
plt.pcolormesh(radar.fields['VR']['data'])
plt.colorbar()
# Out:
# <matplotlib.colorbar.Colorbar instance at 0x108303cb0>

# %%
print radar.range['data']
# Out:
# [     0.    150.    300.    450.    600.    750.    900.   1050.   1200.
#    1350.   1500.   1650.   1800.   1950.   2100.   2250.   2400.   2550.
#    2700.   2850.   3000.   3150.   3300.   3450.   3600.   3750.   3900.
#    4050.   4200.   4350.   4500.   4650.   4800.   4950.   5100.   5250.
#    5400.   5550.   5700.   5850.   6000.   6150.   6300.   6450.   6600.
#    6750.   6900.   7050.   7200.   7350.   7500.   7650.   7800.   7950.
#    8100.   8250.   8400.   8550.   8700.   8850.   9000.   9150.   9300.
#    9450.   9600.   9750.   9900.  10050.  10200.  10350.  10500.  10650.
#   10800.  10950.  11100.  11250.  11400.  11550.  11700.  11850.  12000.
#   12150.  12300.  12450.  12600.  12750.  12900.  13050.  13200.  13350.
#   13500.  13650.  13800.  13950.  14100.  14250.  14400.  14550.  14700.
#   14850.  15000.  15150.  15300.  15450.  15600.  15750.  15900.  16050.
#   16200.  16350.  16500.  16650.  16800.  16950.  17100.  17250.  17400.
#   17550.  17700.  17850.  18000.  18150.  18300.  18450.  18600.  18750.
#   18900.  19050.  19200.  19350.  19500.  19650.  19800.  19950.  20100.
#   20250.  20400.  20550.  20700.  20850.  21000.  21150.  21300.  21450.
#   21600.  21750.  21900.  22050.  22200.  22350.  22500.  22650.  22800.
#   22950.  23100.  23250.  23400.  23550.  23700.  23850.  24000.  24150.
#   24300.  24450.  24600.  24750.  24900.  25050.  25200.  25350.  25500.
#   25650.  25800.  25950.  26100.  26250.  26400.  26550.  26700.  26850.
#   27000.  27150.  27300.  27450.  27600.  27750.  27900.  28050.  28200.
#   28350.  28500.  28650.  28800.  28950.  29100.  29250.  29400.  29550.
#   29700.  29850.  30000.  30150.  30300.  30450.  30600.  30750.  30900.
#   31050.  31200.  31350.  31500.  31650.  31800.  31950.  32100.  32250.
#   32400.  32550.  32700.  32850.  33000.  33150.  33300.  33450.  33600.
#   33750.  33900.  34050.  34200.  34350.  34500.  34650.  34800.  34950.
#   35100.  35250.  35400.  35550.  35700.  35850.  36000.  36150.  36300.
#   36450.  36600.  36750.  36900.  37050.  37200.  37350.  37500.  37650.
#   37800.  37950.  38100.  38250.  38400.  38550.  38700.  38850.  39000.
#   39150.  39300.  39450.  39600.  39750.  39900.  40050.  40200.  40350.
#   40500.  40650.  40800.  40950.  41100.  41250.  41400.  41550.  41700.
#   41850.  42000.  42150.  42300.  42450.  42600.  42750.  42900.  43050.
#   43200.  43350.  43500.  43650.  43800.  43950.  44100.  44250.  44400.
#   44550.  44700.  44850.  45000.  45150.  45300.  45450.  45600.  45750.
#   45900.  46050.  46200.  46350.  46500.  46650.  46800.  46950.  47100.
#   47250.  47400.  47550.  47700.  47850.  48000.  48150.  48300.  48450.
#   48600.  48750.  48900.  49050.  49200.  49350.  49500.  49650.  49800.
#   49950.  50100.  50250.  50400.  50550.  50700.  50850.  51000.  51150.
#   51300.  51450.  51600.  51750.  51900.  52050.  52200.  52350.  52500.
#   52650.  52800.  52950.  53100.  53250.  53400.  53550.  53700.  53850.
#   54000.  54150.  54300.  54450.  54600.  54750.  54900.  55050.  55200.
#   55350.  55500.  55650.  55800.  55950.  56100.  56250.  56400.  56550.
#   56700.  56850.  57000.  57150.  57300.  57450.  57600.  57750.  57900.
#   58050.  58200.  58350.  58500.  58650.  58800.  58950.  59100.  59250.
#   59400.  59550.  59700.  59850.]
