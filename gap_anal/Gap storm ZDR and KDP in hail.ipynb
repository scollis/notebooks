# %% [markdown]
# Polarimetric analysis of the CP2 Data from the time of the Gap Storm.

# %%
import pyart
from matplotlib import pyplot as plt
import numpy as np
from matplotlib import rc
from copy import deepcopy
# %matplotlib inline

# %%
filename = '/data/radar/cp2/063604.mdv'
radar = pyart.io.read(filename)

# %%
print radar.fields.keys()
# Out:
# ['differential_phase', 'cross_correlation_ratio', 'spectrum_width', 'reflectivity', 'differential_reflectivity', 'specific_differential_phase', 'velocity']

# %%
gap_loc = [ 152.9531, -27.4439]

# %%
font = {'size' : 16}
rc('font', **font)
f = plt.figure(figsize=[15,8])
myd = pyart.graph.RadarMapDisplay(radar)
myd.plot_ppi_map('reflectivity', -1, vmin=-8, vmax=72, 
                 min_lon=152.5, max_lon=153.15, min_lat=-27.9, max_lat=-27.4,
                 lon_lines = np.arange(150, 154, .2), 
                 lat_lines = np.arange(-35, -27, .1), resolution = 'h',
                 auto_range=False)



myd.plot_range_ring(25. * 1000.0, line_style = 'k-')
myd.plot_range_ring(50. * 1000.0, line_style = 'k--')

myd.plot_line_xy([-50000.0, 50000.0], [0.0,0.0], line_style = 'k-')
myd.plot_line_xy([0.0,0.0],[-50000.0, 50000.0], line_style = 'k-')

myd.plot_point(radar.longitude['data'], radar.latitude['data'])
myd.plot_point( gap_loc[0], gap_loc[1], symbol = 'ro', label_text='The Gap',  
               label_offset=[0.01, 0.01] )

ax1 = plt.gca()
x0,x1 = ax1.get_xlim()
y0,y1 = ax1.get_ylim()
ax1.set_aspect((x1-x0)/(y1-y0) - .15)

#plt.text(xp, yp, 'foo'

# %%
font = {'size' : 16}
rc('font', **font)
f = plt.figure(figsize=[15,8])
myd = pyart.graph.RadarMapDisplay(radar)
myd.plot_ppi_map('specific_differential_phase', -1, vmin=-2.5, vmax=5, 
                 min_lon=152.5, max_lon=153.15, min_lat=-27.9, max_lat=-27.4,
                 lon_lines = np.arange(150, 154, .2), 
                 lat_lines = np.arange(-35, -27, .1), resolution = 'h',
                 auto_range=False)
myd.plot_range_ring(25. * 1000.0, line_style = 'k-')
myd.plot_range_ring(50. * 1000.0, line_style = 'k--')

myd.plot_line_xy([-50000.0, 50000.0], [0.0,0.0], line_style = 'k-')
myd.plot_line_xy([0.0,0.0],[-50000.0, 50000.0], line_style = 'k-')

myd.plot_point(radar.longitude['data'], radar.latitude['data'])
myd.plot_point( gap_loc[0], gap_loc[1], symbol = 'ro', label_text='The Gap',  
               label_offset=[0.01, 0.01] )

ax1 = plt.gca()
x0,x1 = ax1.get_xlim()
y0,y1 = ax1.get_ylim()
ax1.set_aspect((x1-x0)/(y1-y0) - .15)

#plt.text(xp, yp, 'foo'

# %%
font = {'size' : 16}
rc('font', **font)
f = plt.figure(figsize=[15,8])
myd = pyart.graph.RadarMapDisplay(radar)
myd.plot_ppi_map('cross_correlation_ratio', -1, vmin=0.8, vmax=1, 
                 min_lon=152.5, max_lon=153.15, min_lat=-27.9, max_lat=-27.4,
                 lon_lines = np.arange(150, 154, .2), 
                 lat_lines = np.arange(-35, -27, .1), resolution = 'h',
                 auto_range=False)
myd.plot_range_ring(25. * 1000.0, line_style = 'k-')
myd.plot_range_ring(50. * 1000.0, line_style = 'k--')

myd.plot_line_xy([-50000.0, 50000.0], [0.0,0.0], line_style = 'k-')
myd.plot_line_xy([0.0,0.0],[-50000.0, 50000.0], line_style = 'k-')

myd.plot_point(radar.longitude['data'], radar.latitude['data'])
myd.plot_point( gap_loc[0], gap_loc[1], symbol = 'ro', label_text='The Gap',  
               label_offset=[0.01, 0.01] )

ax1 = plt.gca()
x0,x1 = ax1.get_xlim()
y0,y1 = ax1.get_ylim()
ax1.set_aspect((x1-x0)/(y1-y0) - .15)

#plt.text(xp, yp, 'foo'

# %%
font = {'size' : 16}
rc('font', **font)
f = plt.figure(figsize=[15,8])
myd = pyart.graph.RadarMapDisplay(radar)
myd.plot_ppi_map('differential_reflectivity', -1, vmin=-0.5, vmax=2, 
                 min_lon=152.5, max_lon=153.15, min_lat=-27.9, max_lat=-27.4,
                 lon_lines = np.arange(150, 154, .2), 
                 lat_lines = np.arange(-35, -27, .1), resolution = 'h',
                 auto_range=False)
myd.plot_range_ring(25. * 1000.0, line_style = 'k-')
myd.plot_range_ring(50. * 1000.0, line_style = 'k--')

myd.plot_line_xy([-50000.0, 50000.0], [0.0,0.0], line_style = 'k-')
myd.plot_line_xy([0.0,0.0],[-50000.0, 50000.0], line_style = 'k-')

myd.plot_point(radar.longitude['data'], radar.latitude['data'])
myd.plot_point( gap_loc[0], gap_loc[1], symbol = 'ro', label_text='The Gap',  
               label_offset=[0.01, 0.01] )

ax1 = plt.gca()
x0,x1 = ax1.get_xlim()
y0,y1 = ax1.get_ylim()
ax1.set_aspect((x1-x0)/(y1-y0) - .15)

#plt.text(xp, yp, 'foo'

# %%
smooth_zdr = deepcopy(radar.fields['differential_reflectivity'])
for i in range(smooth_zdr['data'].shape[0]):
    smooth_zdr['data'][i,:] = \
            pyart.correct.phase_proc.smooth_and_trim(smooth_zdr['data'][i,:], 8)

radar.fields.update({'differential_reflectivity_smooth': smooth_zdr})

# %%
font = {'size' : 16}
rc('font', **font)
f = plt.figure(figsize=[15,8])
myd = pyart.graph.RadarMapDisplay(radar)
myd.plot_ppi_map('differential_reflectivity_smooth', -1, vmin=-0.5, vmax=2, 
                 min_lon=152.5, max_lon=153.15, min_lat=-27.9, max_lat=-27.4,
                 lon_lines = np.arange(150, 154, .2), 
                 lat_lines = np.arange(-35, -27, .1), resolution = 'h',
                 auto_range=False)
myd.plot_range_ring(25. * 1000.0, line_style = 'k-')
myd.plot_range_ring(50. * 1000.0, line_style = 'k--')

myd.plot_line_xy([-50000.0, 50000.0], [0.0,0.0], line_style = 'k-')
myd.plot_line_xy([0.0,0.0],[-50000.0, 50000.0], line_style = 'k-')

myd.plot_point(radar.longitude['data'], radar.latitude['data'])
myd.plot_point( gap_loc[0], gap_loc[1], symbol = 'ro', label_text='The Gap',  
               label_offset=[0.01, 0.01] )

ax1 = plt.gca()
x0,x1 = ax1.get_xlim()
y0,y1 = ax1.get_ylim()
ax1.set_aspect((x1-x0)/(y1-y0) - .15)

#plt.text(xp, yp, 'foo'
