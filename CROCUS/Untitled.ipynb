# %%
import sage_data_client

# %%
import sage_data_client

df = sage_data_client.query(
    start="2023-07-02T11:00:00.000Z",
    end="2023-07-09T11:00:00.000Z", 
    filter={
        "plugin": "registry.sagecontinuum.org/jrobrien/waggle-aqt:0.23.5.04.*",
        "vsn": "W08D",
        "name": "aqt.gas.co"
    }
)

# %%
df.value.plot()
# Out:
# <Axes: >
