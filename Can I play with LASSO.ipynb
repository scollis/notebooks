# %%
import netCDF4
from matplotlib import pyplot as plt
import xarray as xr
# %matplotlib inline

# %%
remote_data = xr.open_dataset(
    'http://archive.arm.gov/orders/dodsC/orders/dumask1/202869/THREDDS-Extract/raw_model/sgp20160518_alpha2.varanal_300km_25mb_ls.varanal_300km_25mb_sf.sonde_init.144_144_0000105600.nc',
    decode_times=False)

# %%
remote_data
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 1, x: 144, y: 144, z: 226)
# Coordinates:
#   * time     (time) float32 140.11111
#   * x        (x) float32 0.0 100.0 200.0 300.0 400.0 500.0 600.0 700.0 800.0 ...
#   * y        (y) float32 0.0 100.0 200.0 300.0 400.0 500.0 600.0 700.0 800.0 ...
#   * z        (z) float32 15.0 45.0 75.0 105.0 135.0 165.0 195.0 225.0 255.0 ...
# Data variables:
#     p        (z) float32 974.593 971.149 967.714 964.288 960.872 957.465 ...
#     NC       (time, z, y, x) float32 ...
#     NG       (time, z, y, x) float32 ...
#     NI       (time, z, y, x) float32 ...
#     NR       (time, z, y, x) float32 ...
#     NS       (time, z, y, x) float32 ...
#     PP       (time, z, y, x) float32 ...
#     QG       (time, z, y, x) float32 ...
#     QI       (time, z, y, x) float32 ...
#     QN       (time, z, y, x) float32 ...
#     QP       (time, z, y, x) float32 ...
#     QR       (time, z, y, x) float32 ...
#     QRAD     (time, z, y, x) float32 ...
# ...

# %%
remote_data.W[0,10,:,:].plot()
