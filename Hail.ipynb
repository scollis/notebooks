# %%
import pyart
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
fn ='/data/234845.mdv'
myradar = pyart.io.read(fn)

# %%
print(myradar.fields.keys())
# Out:
# ['differential_phase', 'cross_correlation_ratio', 'normalized_coherent_power', 'spectrum_width', 'corrected_mean_doppler_velocity', 'reflectivity', 'SNR', 'differential_reflectivity', 'specific_differential_phase', 'velocity']

# %%
xlim = [-50, 20]
ylim = [-100,-30]

# %%
nyq = myradar.instrument_parameters['nyquist_velocity']['data'][0]
my_display = pyart.graph.RadarDisplay(myradar)
tilt = 1
f = plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
my_display.plot_ppi('reflectivity', tilt, vmin=-6, vmax=64.0)
plt.xlim(xlim)
plt.ylim(ylim)
plt.subplot(1,2,2)
my_display.plot_ppi('differential_reflectivity', tilt, vmin=-1, vmax=6)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-100, -30)

# %%
nyq = myradar.instrument_parameters['nyquist_velocity']['data'][0]
my_display = pyart.graph.RadarDisplay(myradar)
tilt = 1
f = plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
my_display.plot_ppi('reflectivity', tilt, vmin=-6, vmax=64.0)
plt.xlim(xlim)
plt.ylim(ylim)
plt.subplot(1,2,2)
my_display.plot_ppi('velocity', tilt, vmin=-nyq, vmax=nyq)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-100, -30)

# %%
snr = pyart.retrieve.calculate_snr_from_reflectivity(myradar)
myradar.add_field('SNR', snr, replace_existing = True)
gatefilter = pyart.correct.GateFilter(myradar)
gatefilter.exclude_below('SNR', 10) #Non-Sig

corr_vel = pyart.correct.dealias_region_based(
    myradar, vel_field='velocity', keep_original=False, 
skip_along_ray=100, skip_between_rays=100, gatefilter = gatefilter)
myradar.add_field('corrected_mean_doppler_velocity', corr_vel, True)

# %%
nyq = myradar.instrument_parameters['nyquist_velocity']['data'][0]
my_display = pyart.graph.RadarDisplay(myradar)
tilt = 1
f = plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
my_display.plot_ppi('reflectivity', tilt, vmin=-6, vmax=64.0)
plt.xlim(xlim)
plt.ylim(ylim)
plt.subplot(1,2,2)
my_display.plot_ppi('corrected_mean_doppler_velocity', tilt, vmin=-2.0*nyq, vmax=2.0*nyq)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-100, -30)

# %%
nyq = myradar.instrument_parameters['nyquist_velocity']['data'][0]
my_display = pyart.graph.RadarDisplay(myradar)
tilt = 3
f = plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
my_display.plot_ppi('reflectivity', tilt, vmin=-6, vmax=64.0)
plt.xlim(xlim)
plt.ylim(ylim)
plt.subplot(1,2,2)
my_display.plot_ppi('differential_reflectivity', tilt, vmin=-1, vmax=6)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-100, -30)

# %%
nyq = myradar.instrument_parameters['nyquist_velocity']['data'][0]
my_display = pyart.graph.RadarDisplay(myradar)
tilt = 8
f = plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
my_display.plot_ppi('reflectivity', tilt, vmin=-6, vmax=64.0)
plt.xlim(xlim)
plt.ylim(ylim)
plt.subplot(1,2,2)
my_display.plot_ppi('differential_reflectivity', tilt, vmin=-4, vmax=6)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-100, -30)

# %%
nyq = myradar.instrument_parameters['nyquist_velocity']['data'][0]
my_display = pyart.graph.RadarDisplay(myradar)
tilt = 8
f = plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
my_display.plot_ppi('reflectivity', tilt, vmin=-6, vmax=64.0)
plt.xlim(xlim)
plt.ylim(ylim)
plt.subplot(1,2,2)
my_display.plot_ppi('cross_correlation_ratio', tilt, vmin=0.5, vmax=1)
plt.xlim(xlim)
plt.ylim(ylim)
# Out:
# (-100, -30)

# %%
nyq = myradar.instrument_parameters['nyquist_velocity']['data'][0]
my_display = pyart.graph.RadarDisplay(myradar)
tilt = 1
f = plt.figure(figsize=[15,5])
plt.subplot(1,2,1)
my_display.plot_ppi('reflectivity', tilt, vmin=-6, vmax=64.0)
#plt.xlim([-50,0])
#plt.ylim([-100,-50])
plt.subplot(1,2,2)
my_display.plot_ppi('corrected_mean_doppler_velocity', tilt, vmin=-2.0*nyq, vmax=2.0*nyq)
#plt.xlim([-50,0])
#plt.ylim([-100,-50])
